# %% [markdown]
# ## 신경망 모델
# - 이진 분류: 유방암 예측 사례

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# - 데이터 준비

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
cancer = load_breast_cancer()
cancer.data.shape
# Out:
# (569, 30)

# %%
cancer_std = StandardScaler().fit_transform(cancer.data)

# %% [markdown]
# #### 1. 데이터를 정규/표준화 하지 않은 경우

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, stratify=cancer.target, test_size=0.2, random_state=2023
)

# %% [markdown]
# - 모델 정의

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense       # Fully Connected Network

# %%
model = Sequential([
    Dense(100, input_dim=30, activation='relu'),
    Dense(24, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 100)               3100
#
#  dense_10 (Dense)            (None, 24)                2424
#
#  dense_11 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 5549 (21.68 KB)
# Trainable params: 5549 (21.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# - 모델 설정(컴파일)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# - 모델 학습

# %%
history = model.fit(X_train, y_train,
                    validation_split=0.2,       # 학습중 검증용
                    epochs=100,                  # 반복 횟수
                    batch_size=100)             # 동시에 몇개의 데이터를 메모리에 로드하는가
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 57ms/step - loss: 14.6030 - accuracy: 0.5632 - val_loss: 6.1858 - val_accuracy: 0.4286
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 7.1880 - accuracy: 0.3599 - val_loss: 3.6776 - val_accuracy: 0.4286
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 3.2812 - accuracy: 0.4451 - val_loss: 5.7147 - val_accuracy: 0.5714
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 3.0958 - accuracy: 0.5302 - val_loss: 1.9352 - val_accuracy: 0.4505
# Epoch 5/100
# 4/4 [==============================] - 0s 12ms/step - loss: 2.1928 - accuracy: 0.3709 - val_loss: 0.8121 - val_accuracy: 0.6374
# Epoch 6/100
# 4/4 [==============================] - 0s 13ms/step - loss: 1.4910 - accuracy: 0.6896 - val_loss: 1.1170 - val_accuracy: 0.6703
# Epoch 7/100
# 4/4 [==============================] - 0s 13ms/step - loss: 1.2162 - accuracy: 0.6071 - val_loss: 1.0067 - val_accuracy: 0.5934
# Epoch 8/100
# 4/4 [==============================] - 0s 11ms/step - loss: 1.0126 - accuracy: 0.5714 - val_loss: 0.6143 - val_accuracy: 0.8022
# Epoch 9/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.8734 - accuracy: 0.7885 - val_loss: 0.3742 - val_accuracy: 0.8022
# Epoch 10/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7845 - accuracy: 0.7115 - val_loss: 0.3828 - val_accuracy: 0.8132
# Epoch 11/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6745 - accuracy: 0.7967 - val_loss: 0.2904 - val_accuracy: 0.8791
# Epoch 12/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5977 - accuracy: 0.8516 - val_loss: 0.3605 - val_accuracy: 0.8132
# Epoch 13/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5696 - accuracy: 0.8104 - val_loss: 0.2331 - val_accuracy: 0.8791
# Epoch 14/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5195 - accuracy: 0.8599 - val_loss: 0.2275 - val_accuracy: 0.8901
# Epoch 15/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4844 - accuracy: 0.8874 - val_loss: 0.2251 - val_accuracy: 0.8901
# Epoch 16/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4601 - accuracy: 0.8736 - val_loss: 0.2479 - val_accuracy: 0.8901
# Epoch 17/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4394 - accuracy: 0.8874 - val_loss: 0.2069 - val_accuracy: 0.9121
# Epoch 18/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4107 - accuracy: 0.8956 - val_loss: 0.2303 - val_accuracy: 0.9011
# Epoch 19/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3945 - accuracy: 0.8874 - val_loss: 0.2226 - val_accuracy: 0.9011
# Epoch 20/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3748 - accuracy: 0.8901 - val_loss: 0.1950 - val_accuracy: 0.9341
# Epoch 21/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3578 - accuracy: 0.8956 - val_loss: 0.2218 - val_accuracy: 0.9121
# Epoch 22/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3456 - accuracy: 0.9038 - val_loss: 0.2169 - val_accuracy: 0.9121
# Epoch 23/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.
# Epoch 84/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2025 - accuracy: 0.9203 - val_loss: 0.1752 - val_accuracy: 0.9231
# Epoch 85/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1840 - accuracy: 0.9176 - val_loss: 0.1884 - val_accuracy: 0.9231
# Epoch 86/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1931 - accuracy: 0.9341 - val_loss: 0.1750 - val_accuracy: 0.9341
# Epoch 87/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1943 - accuracy: 0.9176 - val_loss: 0.2010 - val_accuracy: 0.9231
# Epoch 88/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2052 - accuracy: 0.9286 - val_loss: 0.1977 - val_accuracy: 0.9341
# Epoch 89/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2090 - accuracy: 0.9286 - val_loss: 0.2854 - val_accuracy: 0.8681
# Epoch 90/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2098 - accuracy: 0.9176 - val_loss: 0.1709 - val_accuracy: 0.9231
# Epoch 91/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1976 - accuracy: 0.9203 - val_loss: 0.1776 - val_accuracy: 0.9231
# Epoch 92/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1772 - accuracy: 0.9203 - val_loss: 0.1676 - val_accuracy: 0.9231
# Epoch 93/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1807 - accuracy: 0.9258 - val_loss: 0.1669 - val_accuracy: 0.9231
# Epoch 94/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1994 - accuracy: 0.9176 - val_loss: 0.1929 - val_accuracy: 0.9231
# Epoch 95/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1786 - accuracy: 0.9341 - val_loss: 0.1663 - val_accuracy: 0.9231
# Epoch 96/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1839 - accuracy: 0.9176 - val_loss: 0.1673 - val_accuracy: 0.9231
# Epoch 97/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1772 - accuracy: 0.9231 - val_loss: 0.1660 - val_accuracy: 0.9231
# Epoch 98/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1770 - accuracy: 0.9231 - val_loss: 0.1714 - val_accuracy: 0.9231
# Epoch 99/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1717 - accuracy: 0.9231 - val_loss: 0.1702 - val_accuracy: 0.9231
# Epoch 100/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1767 - accuracy: 0.9231 - val_loss: 0.1830 - val_accuracy: 0.9231

# %% [markdown]
# - 모델 평가

# %%
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1886 - accuracy: 0.9123
# [0.18855556845664978, 0.9122806787490845]

# %% [markdown]
# - 훈련과정 시각화
#     - epoch에 따른 accuracy, val_loss의 변화

# %%
y_acc = history.history['accuracy']
y_vloss = history.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,6))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid()
plt.ylim([0,1]), plt.xlabel(['Epoch'])
plt.title('No feature transformation')
plt.show()

# %% [markdown]
# #### 2. 데이터를 표준화한 경우

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(
    cancer_std, cancer.target, stratify=cancer.target, test_size=0.2, random_state=2023
)

# %%
model2 = Sequential()
model2.add(Dense(100, input_shape=(30,), activation='relu'))
model2.add(Dense(24, activation='relu'))
model2.add(Dense(1, activation='sigmoid'))
model2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 100)               3100
#
#  dense_13 (Dense)            (None, 24)                2424
#
#  dense_14 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 5549 (21.68 KB)
# Trainable params: 5549 (21.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 모델 컴파일
model2.compile('adam', 'binary_crossentropy', metrics=['accuracy'])

# %%
# 모델 학습
history2 = model2.fit(X_train2, y_train2, validation_split=0.2,
                      epochs=100, batch_size=100, verbose=0)

# %%
# 모델 평가
model2.evaluate(X_test2, y_test2)
# Out:
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2365 - accuracy: 0.9561
# [0.2365383803844452, 0.9561403393745422]

# %%
# 학습과정 시각화
y_acc2 = history2.history['accuracy']
y_vloss2 = history2.history['val_loss']

plt.figure(figsize=(12,7))
plt.plot(xs, y_acc2, label='train accuracy')
plt.plot(xs, y_vloss2, label='validation loss')
plt.legend(), plt.grid()
plt.ylim([0,1.1]), plt.xlabel(['Epoch'])
plt.title('with feature transformation')
plt.show()
